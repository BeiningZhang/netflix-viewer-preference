# %% [markdown]
# ## The Dataset:
# [Netflix Movies and Shows](https://www.kaggle.com/datasets/maso0dahmed/netflix-movies-and-shows)
#
# ## Description:
# This Notebook is aiming to discover the trends in entertainment, understand preferences among different age groups, and conduct comparative analysis of genres and production locations. It allows for an in-depth understanding of the factors that contribute to the success and popularity of movies and shows on Netflix.

# %%
import numpy as np
import pandas as pd

# Handeling missing data
import missingno as msno

# Visualisation
# from ydata_profiling import ProfileReport
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import required libraries ...

# %%
df = pd.read_csv("imdb_movies_shows.csv")
df.head()
# Out:
#                                  title   type  release_year age_certification  \
# 0  Five Came Back: The Reference Films   SHOW          1945             TV-MA
# 1                          Taxi Driver  MOVIE          1976                 R
# 2      Monty Python and the Holy Grail  MOVIE          1975                PG
# 3                        Life of Brian  MOVIE          1979                 R
# 4                         The Exorcist  MOVIE          1973                 R
#
#    runtime                 genres production_countries  seasons    imdb_id  \
# 0       48      ['documentation']               ['US']      1.0        NaN
# 1      113     ['crime', 'drama']               ['US']      NaN  tt0075314
# 2       91  ['comedy', 'fantasy']               ['GB']      NaN  tt0071853
# 3       94             ['comedy']               ['GB']      NaN  tt0079470
# 4      133             ['horror']               ['US']      NaN  tt0070047
#
#    imdb_score  imdb_votes
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
# [Exploring 🧘 Data 🔡 Analysis with Python: A Comprehensive Guide](https://bootcamp.uxdesign.cc/exploring-data-analysis-with-python-a-comprehensive-guide-e0522ca22665)\
# [A Data Scientist’s Essential Guide to Exploratory Data Analysis](https://towardsdatascience.com/a-data-scientists-essential-guide-to-exploratory-data-analysis-25637eee0cf6)

# %% [markdown]
# ### Handle missing values
#
# [A Guide to Handling Missing values in Python](https://www.kaggle.com/code/parulpandey/a-guide-to-handling-missing-values-in-python)

# %% [markdown]
# ### Data Visualisation

# %% [markdown]
# One of the shortcuts of creating visualisation for EDA in one click is through using Y-profiling method. [YData Profiling](https://docs.profiling.ydata.ai/latest/)

# %%
# profile = ProfileReport(df, title="Profiling Report")
# profile.to_notebook_iframe()

# %% [markdown]
# However, this notebook will still focusing on self-service visualisations.

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="type", data=df, palette="Set2")

# %% [markdown]
# It indicates that Netflix has more movies than shows.

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(x="age_certification", data=df, palette="Set2", 
                   order=df['age_certification'].value_counts().index[0:15])

# %% [markdown]
# * "TV-MA" is a rating assigned by the TV Parental Guidelines to a television program that was designed for mature audiences only.
# * "TV-14" stands for content that may be inappropriate for children younger than 14 years of age.
# * "R" represents films that has been assessed as having material which may be unsuitable for children under the age of 17 by the Motion Picture Association of America; the MPAA writes "Under 17 requires accompanying parent or adult guardian".

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(y="release_year", data=df, palette="Set2", 
                   order=df['release_year'].value_counts().index[0:15])

# %%
df["production_countries"].value_counts()
# Out:
# production_countries
# ['US']                      1950
# ['IN']                       605
# ['JP']                       266
# []                           232
# ['GB']                       219
#                             ...
# ['PR', 'US', 'GB', 'CN']       1
# ['GB', 'US', 'FR']             1
# ['IT', 'ES', 'FR']             1
# ['GB', 'US', 'CZ']             1
# ['NG', 'CA']                   1
# Name: count, Length: 449, dtype: int64

# %% [markdown]
# The feature `country` is in list format. We can expand it to multiple columns like country1 country2 ... calculate the max len of lists.

# %%
sns.set(style="darkgrid")
sns.kdeplot(data=df['runtime'], shade=True)
# Out:
# <Axes: xlabel='runtime', ylabel='Density'>

# %% [markdown]
# According to the correlation matrix, type is highly correlated with seasons, runtime, and age_certification.

# %%
sns.catplot(data=df, x="type", y="seasons")

# %%
sns.catplot(data=df, x="type", y="runtime")

# %%
sns.catplot(data=df, x="type", y="age_certification")
